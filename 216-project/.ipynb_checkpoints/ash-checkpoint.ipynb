# %%
#games won and rebounds
import pandas as pd 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
mvp = pd.read_csv ('data/MVPdata2000_2021.csv') #interested in TRB
adv_stats = pd.read_csv('data/TeamAdvancedStats2000_2021.csv') #orb, drb, trb
game_stats = pd.read_csv('data/TeamPerGameStats2000_2021.csv') #orb, drb, trb test proportions of each?
merged = pd.merge(adv_stats, game_stats,  how='left', left_on=['Year','Team'], right_on = ['Year','Team'])

# %%
merged = merged[['Year', 'Team', 'W', 'L', 'MOV', 'SRS', 'ORB', 'DRB', 'ORB%', 'oppo. DRB%', 'PTS']]
merged = merged.dropna()
merged['Win Rate'] = merged['W'] / (merged['W'] + merged['L'])

# %%
plot = sns.relplot(data=merged, x="ORB%", y="Win Rate")
plot.fig.suptitle("ORB% does not correlate with Win Rate",
                  fontsize=10, x = 0.5)
x = merged['ORB%'].values.reshape(-1,1)
y = merged['Win Rate'].values.reshape(-1,1)
lm = LinearRegression()
lm.fit(x, y)
print("r2: ", lm.score(x,y))
# Out:
# r2:  6.352308316037725e-05

# %%
plot = sns.relplot(data=merged, x="oppo. DRB%", y="Win Rate")
plot.fig.suptitle("DRB% does not correlate with Win Rate",
                  fontsize=10, x = 0.55)
x = merged['oppo. DRB%'].values.reshape(-1,1)
y = merged['Win Rate'].values.reshape(-1,1)
lm = LinearRegression()
lm.fit(x, y)
print("r2: ", lm.score(x,y))
# Out:
# r2:  0.04957841543686137

# %%
plot = sns.lineplot(data=merged, x="Year", y="ORB%").set_title('ORB% has been trending downward')
x = merged['Year'].values.reshape(-1,1)
y = merged['ORB%'].values.reshape(-1,1)
lm = LinearRegression()
lm.fit(x, y)
print("r2: ", lm.score(x,y))
# Out:
# r2:  0.37273910783724895
