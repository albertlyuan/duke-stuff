# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
mvp = pd.read_csv ('data/MVPdata2000_2021.csv') #interested in TRB
adv_stats = pd.read_csv('data/TeamAdvancedStats2000_2021.csv') #orb, drb, trb
game_stats = pd.read_csv('data/TeamPerGameStats2000_2021.csv') #orb, drb, trb test proportions of each?
merged = pd.merge(adv_stats, game_stats,  how='left', left_on=['Year','Team'], right_on = ['Year','Team'])

# %%
merged = merged.dropna()
merged['Win Rate'] = merged['W'] / (merged['W'] + merged['L'])
# Out:
#      Year                    Team   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0    2000      Los Angeles Lakers  29.2  67.0  15.0  64  18  8.55 -0.14  8.41
# 1    2000  Portland Trail Blazers  29.6  59.0  23.0  59  23  6.40 -0.04  6.36
# 2    2000       San Antonio Spurs  30.9  53.0  29.0  58  24  5.94 -0.02  5.92
# 3    2000            Phoenix Suns  28.6  53.0  29.0  56  26  5.22  0.02  5.24
# 4    2000               Utah Jazz  31.5  55.0  27.0  54  28  4.46  0.05  4.52
# ..    ...                     ...   ...   ...   ...  ..  ..   ...   ...   ...
# 609  2019           Atlanta Hawks  25.1  29.0  53.0  27  55 -6.02 -0.04 -6.06
# 610  2019           Chicago Bulls  24.0  22.0  60.0  21  61 -8.41  0.10 -8.32
# 611  2019         New York Knicks  23.4  17.0  65.0  19  63 -9.21  0.28 -8.93
# 612  2019            Phoenix Suns  24.0  19.0  63.0  19  63 -9.34  0.73 -8.61
# 613  2019     Cleveland Cavaliers  25.2  19.0  63.0  19  63 -9.61  0.22 -9.39
#
#      ...   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS  Win Rate
# 0    ...  13.6  33.4  47.0  23.4  7.5  6.5  13.9  22.5  100.8  0.817073
# 1    ...  11.8  31.2  43.0  23.5  7.7  4.8  15.2  22.7   97.5  0.719512
# 2    ...  11.3  32.5  43.8  22.2  7.5  6.7  15.0  20.9   96.2  0.646341
# 3    ...  12.5  31.2  43.7  25.6  9.1  5.3  16.7  24.1   98.9  0.646341
# 4    ...  11.4  29.6  41.0  24.9  7.7  5.4  14.9  24.5   96.5  0.670732
# ..   ...   ...   ...   ...   ...  ...  ...   ...   ...    ...       ...
# 609  ...  11.6  34.5  46.1  25.8  8.2  5.1  17.0  23.6  113.3  0.353659
# 610  ...   8.8  34.1  42.9  21.9  7.4  4.3  14.1  20.3  104.9  0.268293
# 611  ...  10.5  34.3  44.7  20.1  6.8  5.1  14.0  20.9  104.6  0.207317
# 612  ...   9.1  31.3  40.4  23.9  9.0  5.1  15.6  23.6  107.5  0.231707
# 613  ...  10.7  31.9  42.7  20.7  6.5  2.4  13.5  20.0  104.5  0.231707
#
# [595 rows x 52 columns]

# %%
plot = sns.relplot(data=merged, x="STL", y="Win Rate")
plot.fig.suptitle("Steals does not correlate with Win Rate",
                  fontsize=10, x = 0.5)
x = merged['STL'].values.reshape(-1,1)
y = merged['Win Rate'].values.reshape(-1,1)
lm = LinearRegression()
lm.fit(x, y)
print("r2: ", lm.score(x,y))
# Out:
# r2:  0.024157657694447776

# %%
plot = sns.lineplot(data=merged, x="Year", y="STL").set_title('Steals Trend Between 2000-2019')
